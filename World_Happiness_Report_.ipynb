# %% [markdown]
# <a href="https://colab.research.google.com/github/fathiUsman/Analysis-on-World-Happiness-Report/blob/main/World_Happiness_Report_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **World Happiness Report 2015-2021**
#
# focuses on the effects of COVID-19 and how people all over the world have fared.

# %% [markdown]
# **Context**
#
# This notebook deals with the exploratory data analysis of the World Happiness Report. Geographic data is also mapped with these data points such as Region & Sub-region, Latitude & Longitude to identify and visualize more patterns with the happiness index.

# %% [markdown]
#  **Content**
#
# The happiness scores and rankings use data from the Gallup World Poll. The columns such as the happiness score estimate the extent to which each of six factors – economic production, social support, life expectancy, freedom, absence of corruption, and generosity – contribute to making life evaluations higher in each country than they are in Dystopia.

# %% [markdown]
# # **EXPLORATORY DATA ANALYSIS**

# %%
#import pandas,numpy,seaborn,matplotlib packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Read the datas from csv file
df15=pd.read_csv('/content/drive/MyDrive/World-Hapi/2015.csv')
df16=pd.read_csv('/content/drive/MyDrive/World-Hapi/2016.csv')
df17=pd.read_csv('/content/drive/MyDrive/World-Hapi/2017.csv')
df18=pd.read_csv('/content/drive/MyDrive/World-Hapi/2018.csv')
df19=pd.read_csv('/content/drive/MyDrive/World-Hapi/2019.csv')
df20=pd.read_csv('/content/drive/MyDrive/World-Hapi/2020.csv')
df21=pd.read_csv('/content/drive/MyDrive/World-Hapi/2021.csv')

# %%
# Basic information about the data
df15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# **Variables**
#
# **Happiness Score** - Happiness score or subjective well-being. This is the national average response to the question of life evaluations.
#
# **Happiness Rank**- Rank of any country in a particular year.
#
# **Economy GDP per capita** - The GDP-per-capita time series from 2015 to 2021 using countryspecific forecasts of real GDP growth in 2021.
#
# **Family** - Is the national average of the binary responses (either 0 or 1) to the GWP question “If you were in trouble, do you have relatives or friends you can count on to help you whenever you need them, or not.
#
# **Health life expectancy** - Healthy life expectancies at birth are based on the data extracted from the World Health Organization’s (WHO) Global Health Observatory data repository
#
# **Freedom to make life choices**  - Is is the national average of responses to the GWP question “Are you satisfied or dissatisfied with your freedom to choose what you do with your life?
#
# **Generosity**- Generosity is the residual of regressing national average of response to the GWP question “Have you donated money to a charity in the past month?” on GDP per capita.
#
# **Government corruption** - The measure is the national average of the survey responses to two questions in the GWP: “Is corruption widespread throughout the government or not” and “Is corruption widespread within businesses or not?”
#
# **Dystopia**- Hypothetically the saddest country in the world.
#
# More information about a survey: https://worldhappiness.report/ed/2021/

# %%
#renaming the columns
df15.rename(columns={"Happiness Rank": "Rank","Happiness Score":"Score","Economy (GDP per Capita)":"Economy","Health (Life Expectancy)":"Health_Life_Expectancy","Trust (Government Corruption)":"Corruption","Dystopia Residual":"Dystopia"}, inplace= True)
df15.head()
# Out:
#        Country          Region  Rank  ...  Corruption  Generosity  Dystopia
# 0  Switzerland  Western Europe     1  ...     0.41978     0.29678   2.51738
# 1      Iceland  Western Europe     2  ...     0.14145     0.43630   2.70201
# 2      Denmark  Western Europe     3  ...     0.48357     0.34139   2.49204
# 3       Norway  Western Europe     4  ...     0.36503     0.34699   2.46531
# 4       Canada   North America     5  ...     0.32957     0.45811   2.45176
#
# [5 rows x 12 columns]

# %%
df15.drop("Standard Error",axis=1,inplace=True)
df15
# Out:
#          Country                           Region  ...  Generosity  Dystopia
# 0    Switzerland                   Western Europe  ...     0.29678   2.51738
# 1        Iceland                   Western Europe  ...     0.43630   2.70201
# 2        Denmark                   Western Europe  ...     0.34139   2.49204
# 3         Norway                   Western Europe  ...     0.34699   2.46531
# 4         Canada                    North America  ...     0.45811   2.45176
# ..           ...                              ...  ...         ...       ...
# 153       Rwanda               Sub-Saharan Africa  ...     0.22628   0.67042
# 154        Benin               Sub-Saharan Africa  ...     0.18260   1.63328
# 155        Syria  Middle East and Northern Africa  ...     0.47179   0.32858
# 156      Burundi               Sub-Saharan Africa  ...     0.19727   1.83302
# 157         Togo               Sub-Saharan Africa  ...     0.16681   1.56726
#
# [158 rows x 11 columns]

# %%
#renaming the columns
df16.rename(columns={"Happiness Rank": "Rank","Health (Life Expectancy)":"Health_Life_Expectancy","Happiness Score":"Score","Economy (GDP per Capita)":"Economy","Health":"Health_Life_Expectancy","Trust (Government Corruption)":"Corruption","Dystopia Residual":"Dystopia"}, inplace= True)
df16.head()
# Out:
#        Country          Region  Rank  ...  Corruption  Generosity  Dystopia
# 0      Denmark  Western Europe     1  ...     0.44453     0.36171   2.73939
# 1  Switzerland  Western Europe     2  ...     0.41203     0.28083   2.69463
# 2      Iceland  Western Europe     3  ...     0.14975     0.47678   2.83137
# 3       Norway  Western Europe     4  ...     0.35776     0.37895   2.66465
# 4      Finland  Western Europe     5  ...     0.41004     0.25492   2.82596
#
# [5 rows x 13 columns]

# %%
#renaming the columns
df17.rename(columns={"Happiness.Rank": "Rank","Happiness.Score":"Score","Economy..GDP.per.Capita.":"Economy","Health..Life.Expectancy.":"Health_Life_Expectancy","Dystopia.Residual":"Dystopia","Trust..Government.Corruption.":"Corruption"}, inplace= True)
df17.head()
# Out:
#        Country  Rank  Score  ...  Generosity  Corruption  Dystopia
# 0       Norway     1  7.537  ...    0.362012    0.315964  2.277027
# 1      Denmark     2  7.522  ...    0.355280    0.400770  2.313707
# 2      Iceland     3  7.504  ...    0.475540    0.153527  2.322715
# 3  Switzerland     4  7.494  ...    0.290549    0.367007  2.276716
# 4      Finland     5  7.469  ...    0.245483    0.382612  2.430182
#
# [5 rows x 12 columns]

# %%
#renaming the columns
df18.rename(columns={"Overall rank": "Rank","Healthy life expectancy":"Health_Life_Expectancy","GDP per capita":"Economy","Country or region":"Country","Freedom to make life choices":"Freedom","Social support":"Family","Health":"Health_Life_Expectancy","Perceptions of corruption":"Corruption"}, inplace= True)
df18.head()
# Out:
#    Rank      Country  Score  ...  Freedom  Generosity  Corruption
# 0     1      Finland  7.632  ...    0.681       0.202       0.393
# 1     2       Norway  7.594  ...    0.686       0.286       0.340
# 2     3      Denmark  7.555  ...    0.683       0.284       0.408
# 3     4      Iceland  7.495  ...    0.677       0.353       0.138
# 4     5  Switzerland  7.487  ...    0.660       0.256       0.357
#
# [5 rows x 9 columns]

# %%
#renaming the columns
df19.rename(columns={"Overall rank": "Rank","Country or region":"Country","Freedom to make life choices":"Freedom","Social support":"Family","GDP per capita":"Economy","Perceptions of corruption":"Corruption"}, inplace= True)
df19.rename(columns={"Healthy life expectancy":"Health_Life_Expectancy"},inplace=True)
df19.head()
# Out:
#    Rank      Country  Score  ...  Freedom  Generosity  Corruption
# 0     1      Finland  7.769  ...    0.596       0.153       0.393
# 1     2      Denmark  7.600  ...    0.592       0.252       0.410
# 2     3       Norway  7.554  ...    0.603       0.271       0.341
# 3     4      Iceland  7.494  ...    0.591       0.354       0.118
# 4     5  Netherlands  7.488  ...    0.557       0.322       0.298
#
# [5 rows x 9 columns]

# %%
#renaming the columns
df20.rename(columns={"Country name":"Country","Healthy life expectancy":"Health_Life_Expectancy","Ladder score":"Score","Regional indicator":"Region","Freedom to make life choices":"Freedom","Social support":"Family","Health":"Life_Expectancy","Perceptions of corruption":"Corruption"}, inplace= True)
df20.head()
# Out:
#        Country          Region   Score  ...  Generosity  Corruption  Dystopia
# 0      Finland  Western Europe  7.8087  ...   -0.059482    0.195445   2.762835
# 1      Denmark  Western Europe  7.6456  ...    0.066202    0.168489   2.432741
# 2  Switzerland  Western Europe  7.5599  ...    0.105911    0.303728   2.350267
# 3      Iceland  Western Europe  7.5045  ...    0.246944    0.711710   2.460688
# 4       Norway  Western Europe  7.4880  ...    0.134533    0.263218   2.168266
#
# [5 rows x 13 columns]

# %%
#renaming the columns
df21.rename(columns={"Country name":"Country","Ladder score": "Score","Healthy life expectancy":"Health_Life_Expectancy","Regional indicator":"Region","Explained by: Log GDP per capita":"Economy","Freedom to make life choices":"Freedom","Social support":"Family","Perceptions of corruption":"Corruption"}, inplace= True)
df21.head()
# Out:
#        Country  ... Dystopia + residual
# 0      Finland  ...               3.253
# 1      Denmark  ...               2.868
# 2  Switzerland  ...               2.839
# 3      Iceland  ...               2.967
# 4  Netherlands  ...               2.798
#
# [5 rows x 20 columns]

# %%
#df21.drop("Explained by: Social support",axis=1,inplace=True)
#df21.drop("Dystopia",axis=1,inplace=True)
#df21.drop("lowerwhisker",axis=1,inplace=True)
#df21.drop("Logged GDP per capita",axis=1,inplace=True)
df21
# Out:
#          Country  ... Dystopia + residual
# 0        Finland  ...               3.253
# 1        Denmark  ...               2.868
# 2    Switzerland  ...               2.839
# 3        Iceland  ...               2.967
# 4    Netherlands  ...               2.798
# ..           ...  ...                 ...
# 144      Lesotho  ...               1.800
# 145     Botswana  ...               0.648
# 146       Rwanda  ...               1.095
# 147     Zimbabwe  ...               1.205
# 148  Afghanistan  ...               1.895
#
# [149 rows x 20 columns]

# %%
# check null values
df18.isnull().sum()
# Out:
# Rank                      0
# Country                   0
# Score                     0
# Economy                   0
# Family                    0
# Health_Life_Expectancy    0
# Freedom                   0
# Generosity                0
# Corruption                1
# dtype: int64

# %%
# The shape of the dataset can be viewed by using 'shape'
df21.shape
# Out:
# (149, 20)

# %%
# describe( ) is used to view the numerical attributes in the data
#(include='all)-->Describing all columns of a DataFrame regardless of data type.

df21.describe(include='all')
# Out:
#        Country  ... Dystopia + residual
# count      149  ...          149.000000
# unique     149  ...                 NaN
# top      Nepal  ...                 NaN
# freq         1  ...                 NaN
# mean       NaN  ...            2.430329
# std        NaN  ...            0.537645
# min        NaN  ...            0.648000
# 25%        NaN  ...            2.138000
# 50%        NaN  ...            2.509000
# 75%        NaN  ...            2.794000
# max        NaN  ...            3.482000
#
# [11 rows x 20 columns]

# %%
India20=df20[df20['Country']=='India']
India20
# Out:
#     Country      Region   Score  ...  Generosity  Corruption  Dystopia
# 143   India  South Asia  3.5733  ...    0.057552    0.772043   0.734131
#
# [1 rows x 13 columns]

# %%
India_2020=India20.copy()
India_2020
# Out:
#     Country      Region   Score  ...  Generosity  Corruption  Dystopia
# 143   India  South Asia  3.5733  ...    0.057552    0.772043   0.734131
#
# [1 rows x 13 columns]

# %%
India_2020.drop(['Standard error of ladder score','upperwhisker','lowerwhisker','Logged GDP per capita'],axis=1,inplace=True)

# %%
India_2020
# Out:
#     Country      Region   Score  ...  Generosity  Corruption  Dystopia
# 143   India  South Asia  3.5733  ...    0.057552    0.772043   0.734131
#
# [1 rows x 9 columns]

# %%
India_2020
# Out:
#     Country      Region   Score  ...  Generosity  Corruption  Dystopia
# 143   India  South Asia  3.5733  ...    0.057552    0.772043   0.734131
#
# [1 rows x 9 columns]

# %%
#India_2020.insert(2,"Region","South Asia")
India_2020
# Out:
#     Country      Region   Score  ...  Generosity  Corruption  Dystopia
# 143   India  South Asia  3.5733  ...    0.057552    0.772043   0.734131
#
# [1 rows x 9 columns]

# %%
India_2020.insert(2,"Year",2020)
India_2020
# Out:
#     Country      Region  Year  ...  Generosity  Corruption  Dystopia
# 143   India  South Asia  2020  ...    0.057552    0.772043   0.734131
#
# [1 rows x 10 columns]

# %%
India_2020.insert(3,"Economy",0.714745	)
India_2020
# Out:
#     Country      Region  Year  ...  Generosity  Corruption  Dystopia
# 143   India  South Asia  2020  ...    0.057552    0.772043   0.734131
#
# [1 rows x 11 columns]

# %%
India_2020.insert(2,"Rank",144)
India_2020
# Out:
#     Country      Region  Rank  ...  Generosity  Corruption  Dystopia
# 143   India  South Asia   144  ...    0.057552    0.772043   0.734131
#
# [1 rows x 12 columns]

# %%
India19=df19[df19['Country']=='India']
India19
# Out:
#      Rank Country  Score  ...  Freedom  Generosity  Corruption
# 139   140   India  4.015  ...    0.498         0.2       0.085
#
# [1 rows x 9 columns]

# %%
India19.insert(9,"Dystopia",1.519117)
India19
# Out:
#      Rank Country  Score  Economy  ...  Freedom  Generosity  Corruption  Dystopia
# 139   140   India  4.015    0.755  ...    0.498         0.2       0.085  1.519117
#
# [1 rows x 10 columns]

# %%
India_2019=India19.copy(deep=False)
India_2019
# Out:
#      Rank Country  Score  Economy  ...  Freedom  Generosity  Corruption  Dystopia
# 139   140   India  4.015    0.755  ...    0.498         0.2       0.085  1.519117
#
# [1 rows x 10 columns]

# %%
India_2019.insert(2,"Region","South Asia")
India_2019
# Out:
#      Rank Country      Region  Score  ...  Freedom  Generosity  Corruption  Dystopia
# 139   140   India  South Asia  4.015  ...    0.498         0.2       0.085  1.519117
#
# [1 rows x 11 columns]

# %%
India_2019.insert(2,"Year",2019)
India_2019
# Out:
#      Rank Country  Year      Region  ...  Freedom  Generosity  Corruption  Dystopia
# 139   140   India  2019  South Asia  ...    0.498         0.2       0.085  1.519117
#
# [1 rows x 12 columns]

# %%
India18=df18[df18['Country']=='India']
India18
# Out:
#      Rank Country  Score  ...  Freedom  Generosity  Corruption
# 132   133   India   4.19  ...    0.539       0.172       0.093
#
# [1 rows x 9 columns]

# %%
India18.insert(9,"Dystopia",1.46517)

# %%
India18.insert(2,"Region","South Asia")
India18
# Out:
#      Rank Country      Region  Score  ...  Freedom  Generosity  Corruption  Dystopia
# 132   133   India  South Asia   4.19  ...    0.539       0.172       0.093   1.46517
#
# [1 rows x 11 columns]

# %%
India_2018=India18.copy(deep=False)
India_2018
# Out:
#      Rank Country      Region  Score  ...  Freedom  Generosity  Corruption  Dystopia
# 132   133   India  South Asia   4.19  ...    0.539       0.172       0.093   1.46517
#
# [1 rows x 11 columns]

# %%
India_2018.insert(2,"Year",2018)
India_2018
# Out:
#      Rank Country  Year      Region  ...  Freedom  Generosity  Corruption  Dystopia
# 132   133   India  2018  South Asia  ...    0.539       0.172       0.093   1.46517
#
# [1 rows x 12 columns]

# %%
India17=df17[df17['Country']=='India']
India17
# Out:
#     Country  Rank  Score  ...  Generosity  Corruption  Dystopia
# 121   India   122  4.315  ...    0.231538    0.092227  1.519117
#
# [1 rows x 12 columns]

# %%
India_2017=India17.copy(deep=False)
India_2017
# Out:
#     Country  Rank  Score  ...  Generosity  Corruption  Dystopia
# 121   India   122  4.315  ...    0.231538    0.092227  1.519117
#
# [1 rows x 12 columns]

# %%
India_2017.drop(['Whisker.high','Whisker.low'],axis=1,inplace=True)
India_2017
# Out:
#     Country  Rank  Score   Economy  ...   Freedom  Generosity  Corruption  Dystopia
# 121   India   122  4.315  0.792221  ...  0.469987    0.231538    0.092227  1.519117
#
# [1 rows x 10 columns]

# %%
India_2017.insert(2,"Year",2017)
India_2017
# Out:
#     Country  Rank  Year  Score  ...   Freedom  Generosity  Corruption  Dystopia
# 121   India   122  2017  4.315  ...  0.469987    0.231538    0.092227  1.519117
#
# [1 rows x 11 columns]

# %%
India_2017.insert(2,"Region","South Asia")
India_2017
# Out:
#     Country  Rank      Region  Year  ...   Freedom  Generosity  Corruption  Dystopia
# 121   India   122  South Asia  2017  ...  0.469987    0.231538    0.092227  1.519117
#
# [1 rows x 12 columns]

# %%
India16=df16[df16['Country']=='India']
India16
# Out:
#     Country         Region  Rank  ...  Corruption  Generosity  Dystopia
# 117   India  Southern Asia   118  ...     0.08722     0.25028   2.18032
#
# [1 rows x 13 columns]

# %%
India_2016=India16.copy(deep=False)
India_2016
# Out:
#     Country         Region  Rank  ...  Corruption  Generosity  Dystopia
# 117   India  Southern Asia   118  ...     0.08722     0.25028   2.18032
#
# [1 rows x 13 columns]

# %%
India_2016.drop(['Lower Confidence Interval','Upper Confidence Interval'],axis=1,inplace=True)
India_2016
# Out:
#     Country         Region  Rank  ...  Corruption  Generosity  Dystopia
# 117   India  Southern Asia   118  ...     0.08722     0.25028   2.18032
#
# [1 rows x 11 columns]

# %%
India_2016.insert(2,"Year",2016)
India_2016
# Out:
#     Country         Region  Year  ...  Corruption  Generosity  Dystopia
# 117   India  Southern Asia  2016  ...     0.08722     0.25028   2.18032
#
# [1 rows x 12 columns]

# %%
India15=df15[df15['Country']=='India']
India15
# Out:
#     Country         Region  Rank  ...  Corruption  Generosity  Dystopia
# 116   India  Southern Asia   117  ...     0.08492     0.26475   2.27513
#
# [1 rows x 11 columns]

# %%
India_2015=India15.copy(deep=False)
India_2015
# Out:
#     Country         Region  Rank  ...  Corruption  Generosity  Dystopia
# 116   India  Southern Asia   117  ...     0.08492     0.26475   2.27513
#
# [1 rows x 11 columns]

# %%
India_2015.insert(2,"Year",2015)
India_2015
# Out:
#     Country         Region  Year  ...  Corruption  Generosity  Dystopia
# 116   India  Southern Asia  2015  ...     0.08492     0.26475   2.27513
#
# [1 rows x 12 columns]

# %%
India21=df21[df21['Country']=='India']
India21
# Out:
#     Country  ... Dystopia + residual
# 138   India  ...               1.405
#
# [1 rows x 20 columns]

# %%
India_2021=India21.copy(deep=False)
India_2021
# Out:
#     Country  ... Dystopia + residual
# 138   India  ...               1.405
#
# [1 rows x 20 columns]

# %%
India_2021.drop(['Standard error of ladder score','upperwhisker','lowerwhisker','Explained by: Perceptions of corruption','Logged GDP per capita','Explained by: Generosity','Explained by: Freedom to make life choices','Explained by: Social support','Explained by: Healthy life expectancy'],axis=1,inplace=True)

# %%
India_2021.drop(['Dystopia + residual'],axis=1,inplace=True)

# %%
India_2021.insert(2,"Year",2021)
India_2021
# Out:
#     Country      Region  Year  ...  Corruption  Ladder score in Dystopia  Economy
# 138   India  South Asia  2021  ...       0.774                      2.43    0.741
#
# [1 rows x 11 columns]

# %%
India_2021
# Out:
#     Country      Region  Year  ...  Corruption  Ladder score in Dystopia  Economy
# 138   India  South Asia  2021  ...       0.774                      2.43    0.741
#
# [1 rows x 11 columns]

# %%
India_2021.rename(columns={'Ladder score in Dystopia':'Dystopia'},inplace=True)

# %%
India_2021.insert(2,"Rank",139)
India_2021
# Out:
#     Country      Region  Rank  Year  ...  Generosity  Corruption  Dystopia  Economy
# 138   India  South Asia   139  2021  ...       0.089       0.774      2.43    0.741
#
# [1 rows x 12 columns]

# %%
India_2021
# Out:
#     Country      Region  Rank  Year  ...  Generosity  Corruption  Dystopia  Economy
# 138   India  South Asia   139  2021  ...       0.089       0.774      2.43    0.741
#
# [1 rows x 12 columns]

# %%
India_2020
# Out:
#     Country      Region  Rank  ...  Generosity  Corruption  Dystopia
# 143   India  South Asia   144  ...    0.057552    0.772043   0.734131
#
# [1 rows x 12 columns]

# %%
India_2019
# Out:
#      Rank Country  Year      Region  ...  Freedom  Generosity  Corruption  Dystopia
# 139   140   India  2019  South Asia  ...    0.498         0.2       0.085  1.519117
#
# [1 rows x 12 columns]

# %%
India_2018
# Out:
#      Rank Country  Year      Region  ...  Freedom  Generosity  Corruption  Dystopia
# 132   133   India  2018  South Asia  ...    0.539       0.172       0.093   1.46517
#
# [1 rows x 12 columns]

# %%
India_2017
# Out:
#     Country  Rank      Region  Year  ...   Freedom  Generosity  Corruption  Dystopia
# 121   India   122  South Asia  2017  ...  0.469987    0.231538    0.092227  1.519117
#
# [1 rows x 12 columns]

# %%
India_2016
# Out:
#     Country         Region  Year  ...  Corruption  Generosity  Dystopia
# 117   India  Southern Asia  2016  ...     0.08722     0.25028   2.18032
#
# [1 rows x 12 columns]

# %%
India_2015
# Out:
#     Country         Region  Year  ...  Corruption  Generosity  Dystopia
# 116   India  Southern Asia  2015  ...     0.08492     0.26475   2.27513
#
# [1 rows x 12 columns]

# %%
India_2015.shape
# Out:
# (1, 12)

# %%
India_2016.shape
# Out:
# (1, 12)

# %%
India_2017.shape
# Out:
# (1, 12)

# %%
India_2018.shape
# Out:
# (1, 12)

# %%
India_2019.shape
# Out:
# (1, 12)

# %%
India_2020.shape
# Out:
# (1, 12)

# %%
India_2021.shape
# Out:
# (1, 12)

# %%
from functools import reduce

# compile the list of dataframes you want to merge
data_frames = [India_2015,India_2016,India_2017,India_2018,India_2019,India_2020,India_2021]
INDIA= reduce(lambda  left,right: pd.merge(left,right,
                                            how='outer'), data_frames)

# %%
INDIA
# Out:
#   Country         Region  Year  ...  Generosity  Dystopia  Dystopia
# 0   India  Southern Asia  2015  ...    0.264750  2.275130        NaN
# 1   India  Southern Asia  2016  ...    0.250280  2.180320        NaN
# 2   India     South Asia  2017  ...    0.231538  1.519117        NaN
# 3   India     South Asia  2018  ...    0.172000  1.465170        NaN
# 4   India     South Asia  2019  ...    0.200000  1.519117        NaN
# 5   India     South Asia  2020  ...    0.057552       NaN   0.734131
# 6   India     South Asia  2021  ...    0.089000  2.430000        NaN
#
# [7 rows x 13 columns]

# %%
INDIA.drop(INDIA.columns[12],axis=1,inplace=True)
INDIA
# Out:
#   Country         Region  Year  ...  Corruption  Generosity  Dystopia
# 0   India  Southern Asia  2015  ...    0.084920    0.264750  2.275130
# 1   India  Southern Asia  2016  ...    0.087220    0.250280  2.180320
# 2   India     South Asia  2017  ...    0.092227    0.231538  1.519117
# 3   India     South Asia  2018  ...    0.093000    0.172000  1.465170
# 4   India     South Asia  2019  ...    0.085000    0.200000  1.519117
# 5   India     South Asia  2020  ...    0.772043    0.057552       NaN
# 6   India     South Asia  2021  ...    0.774000    0.089000  2.430000
#
# [7 rows x 12 columns]

# %%
values = {"Dystopia":0.734131}
INDIA.fillna(value=values,inplace=True)

# %%
INDIA["Health_Life_Expectancy"].replace({60.215187:0.602151,60.633000:0.606330 },inplace=True)

INDIA
# Out:
#   Country         Region  Year  ...  Corruption  Generosity  Dystopia
# 0   India  Southern Asia  2015  ...    0.084920    0.264750  2.275130
# 1   India  Southern Asia  2016  ...    0.087220    0.250280  2.180320
# 2   India     South Asia  2017  ...    0.092227    0.231538  1.519117
# 3   India     South Asia  2018  ...    0.093000    0.172000  1.465170
# 4   India     South Asia  2019  ...    0.085000    0.200000  1.519117
# 5   India     South Asia  2020  ...    0.772043    0.057552  0.734131
# 6   India     South Asia  2021  ...    0.774000    0.089000  2.430000
#
# [7 rows x 12 columns]

# %% [markdown]
# # **India from 2015 to 2021**

# %%
plt.figure(figsize=(10,4))
sns.lineplot(data=INDIA,x="Year",y="Economy",marker='o')
plt.title("Indian Economy 2015-2021")
plt.show()

# %% [markdown]
# There are certain peaks with regards to Economy as seen in the years 2016 and 2017. A drop as seen in the year 2018 .There is a slight peak in the economy in year 2019 compared to 2018. In 2020,The economy has dropped down and in 2021,its little improved.

# %%
plt.figure(figsize=(10,4))
sns.lineplot(data=INDIA,x="Year",y="Family",marker='o')
plt.title("Social Support")
plt.show()

# %% [markdown]
# There are distinct highs in 2017, 2018 and 2019, 2016 being the lowest.In 2020 and 2021 ,India's social support is on a decreasing trend compared to earlier years.

# %%
plt.figure(figsize=(8,6))
sns.heatmap(INDIA.corr(),annot=True)
plt.show()

# %%
INDIA.corr()
# Out:
#                             Year      Rank  ...  Generosity  Dystopia
# Year                    1.000000  0.931245  ...   -0.909290 -0.313577
# Rank                    0.931245  1.000000  ...   -0.870876 -0.528822
# Score                  -0.934069 -0.937074  ...    0.955795  0.536248
# Economy                 0.340564  0.193604  ...   -0.084212 -0.214719
# Family                  0.519968  0.573568  ...   -0.322492 -0.522223
# Health_Life_Expectancy  0.410085  0.532916  ...   -0.679294 -0.736066
# Freedom                 0.892246  0.793391  ...   -0.976481 -0.272783
# Corruption              0.792130  0.671451  ...   -0.917874 -0.173053
# Generosity             -0.909290 -0.870876  ...    1.000000  0.428764
# Dystopia               -0.313577 -0.528822  ...    0.428764  1.000000
#
# [10 rows x 10 columns]

# %%
India_c=INDIA.copy(deep=False)

# %%
India_c
# Out:
#   Country         Region  Year  ...  Corruption  Generosity  Dystopia
# 0   India  Southern Asia  2015  ...    0.084920    0.264750  2.275130
# 1   India  Southern Asia  2016  ...    0.087220    0.250280  2.180320
# 2   India     South Asia  2017  ...    0.092227    0.231538  1.519117
# 3   India     South Asia  2018  ...    0.093000    0.172000  1.465170
# 4   India     South Asia  2019  ...    0.085000    0.200000  1.519117
# 5   India     South Asia  2020  ...    0.772043    0.057552  0.734131
# 6   India     South Asia  2021  ...    0.774000    0.089000  2.430000
#
# [7 rows x 12 columns]

# %%
India_c.drop(['Family','Health_Life_Expectancy','Generosity','Dystopia'],axis=1,inplace=True)

# %%
India_c
# Out:
#   Country         Region  Year  Rank   Score   Economy   Freedom  Corruption
# 0   India  Southern Asia  2015   117  4.5650  0.644990  0.397860    0.084920
# 1   India  Southern Asia  2016   118  4.4040  0.740360  0.402850    0.087220
# 2   India     South Asia  2017   122  4.3150  0.792221  0.469987    0.092227
# 3   India     South Asia  2018   133  4.1900  0.721000  0.539000    0.093000
# 4   India     South Asia  2019   140  4.0150  0.755000  0.498000    0.085000
# 5   India     South Asia  2020   144  3.5733  0.714745  0.881445    0.772043
# 6   India     South Asia  2021   139  3.8190  0.741000  0.893000    0.774000

# %%
corr1=India_c.corr(method='pearson')
plt.figure(figsize=(10,6))
sns.heatmap(corr1,annot=True)
plt.show()

# %% [markdown]
# **1.How is Economy related to Happiness Score?**
#
# From the heatmaps,Correlation coefficient between Economy and Score is -0.22  indicating a negative relationship between the satisfaction of citizens with the economy and the Happiness score. GDP_per capita(Economy) is a tracker of the economic growth of a country. People in countries showing positive growth rate of economies tend to be more happier as it leads to higher incomes and better standards of living. But,In India, the Economy is not satisfied with the Government.
#
# **Relation of Freedom to Happiness Score?**
#
# The correlation coefficient between Freedom and Score is -0.91 indicating a negative relationship between the perception of Freedom and the Happiness Score of a country. Generalising this perception of freedom is a hard task because according to research it is different for people. Nevertheless, it is still a significant contributor to the Happiness Score of a nation.
#
# **How does corruption affect the Happiness score?**
#
# Correlation coefficient between corruption and Score is ~-0.85. This indicates a negative relationship between perception of corruption and the happiness score of a country.

# %% [markdown]
# ***Ranking distribution of all Countries in year 2020 according to the Happiness Score ***

# %%
plt.figure(figsize=(35,10))
sns.barplot(data=df20,x="Country",y="Score")
plt.xticks(rotation=90) 
plt.show()

# %% [markdown]
# In 2020,Finland ranks on the top and Afganistan in the least according to the happiness score.
# India is in 145th position in the world.

# %% [markdown]
# **Ranking distribution of all Countries in year 2021 according to the Happiness Score**

# %%
plt.figure(figsize=(35,10))
sns.barplot(data=df21,x="Country",y="Score")
plt.xticks(rotation=90) 
plt.show()

# %% [markdown]
# In 2021,Finland ranks on the top and Afganistan in the least according to the happiness score.
# India is in 140th position in the world.
#
# So concluded as India's happiness score has relatively increased in 2021 compared to 2020.
# Due to the impact of covid19,The Indian citizens were comparatively gone depressed in 2020 but in 2021 the country has improved.But comparing to other countries India's Happiness score is low.

# %% [markdown]
# **Distribution of scores across different countries**

# %% [markdown]
# **Have people been relatively more happier in coming years?**

# %%
#setting a darkgrid style for each visualisation
sns.set_style("darkgrid")

# %%
plt.figure(figsize=(10,6))
a=10
plt.hist(df20.Score,a,label='2020',alpha=0.3,color='red')
plt.hist(df21.Score,a,label='2021',alpha=0.5,color='blue')
plt.ylabel("No. of countries",color='black',size=13)
plt.legend(loc='upper right')
plt.title("Distribution of Happiness scores across 2020,2021",color='red',size=16)
plt.show()

# %% [markdown]
# The stacked histogram plotted above shows that there has been an increase in the happiness score at the extremums as there appears to be a shift to the right in the year 2021. A significant increase in the number of countries with score between 5-6 has been observed. This may signify relatively better living standards and satisfaction of the people with their lives and the government in 2021.
#
# We can conclude that people have been happier in 2021 as compared to 2020.

# %%
plt.figure(figsize=(10,6))
a=10
plt.hist(df18.Score,a,label='2018',alpha=0.3,color='green')
plt.hist(df19.Score,a,label='2019',alpha=0.5,color='blue')
plt.ylabel("No. of countries",color='black',size=13)
plt.legend(loc='upper right')
plt.title("Distribution of Happiness scores across 2018,2019",color='red',size=16)
plt.show()

# %% [markdown]
# The stacked histogram plotted above shows that there has been an increase in the happiness score at the extremums as there appears to be a shift to the right in the year 2019. A significant increase in the number of countries with score between 4-5 has been observed. This may signify relatively better living standards and satisfaction of the people with their lives and the government in 2019.
#
# We can conclude that people have been happier in 2019 as compared to 2018.

# %% [markdown]
# **Correlating features with the happiness scores**
#
# Is there a strong relation between happiness scores of a country and its economic and legal state?
#
# To answer this we will find out the correlation values between Happiness Scores and:
#
# corr_perception
# GDP_per_capita
# Freedom
# across the three datasets.

# %% [markdown]
# **India in Asia**

# %%
Southeast_Asia=df21[df21['Region']== 'Southeast Asia']

# %%
South_Asia=df21[df21['Region']== 'South Asia']

# %%
East_Asia=df21[df21['Region']== 'East Asia']

# %% [markdown]
# **Grouping the Country name and the happiness score of year 2021**

# %%
df_2021 =df21 [(df21["Country"]=="Bhutan") |(df21["Country"]=="China")|(df21["Country"]=='Nepal') |(df21["Country"]=='Afghanistan')|(df21["Country"]=='India')|(df21["Country"]=='Pakistan')|(df21["Country"]=='Bangladesh')|(df21["Country"]=='Myanmar')]
df_2021
# Out:
#          Country  ... Dystopia + residual
# 83         China  ...               1.982
# 86         Nepal  ...               2.642
# 100   Bangladesh  ...               2.427
# 104     Pakistan  ...               2.784
# 125      Myanmar  ...               1.407
# 138        India  ...               1.405
# 148  Afghanistan  ...               1.895
#
# [7 rows x 20 columns]

# %%
Asia = df_2021.groupby('Country')['Score'].sum().reset_index()
Asia
# Out:
#        Country  Score
# 0  Afghanistan  2.523
# 1   Bangladesh  5.025
# 2        China  5.339
# 3        India  3.819
# 4      Myanmar  4.426
# 5        Nepal  5.269
# 6     Pakistan  4.934

# %%
plt.figure(figsize = (15,8))
plt.pie(Asia.Score,labels=Asia.Country,autopct='%1.3f%%',explode=[0,0,0,0.2,0,0,0])
plt.show()

# %% [markdown]
# The happiness score of India and neighbouring countries are plotted in as a pie chart.
# From this,we can observe that in 2021,China has the highest score.

# %% [markdown]
# **Visualisation of Dystopia of Asian countries**

# %%
Asia1 = df_2021.groupby('Country')['Dystopia + residual'].sum().reset_index()
Asia1
# Out:
#        Country  Dystopia + residual
# 0  Afghanistan                1.895
# 1   Bangladesh                2.427
# 2        China                1.982
# 3        India                1.405
# 4      Myanmar                1.407
# 5        Nepal                2.642
# 6     Pakistan                2.784

# %%
Asia1.rename(columns={'Dystopia + residual':'Dystopia'},inplace=True)
Asia1
# Out:
#        Country  Dystopia
# 0  Afghanistan     1.895
# 1   Bangladesh     2.427
# 2        China     1.982
# 3        India     1.405
# 4      Myanmar     1.407
# 5        Nepal     2.642
# 6     Pakistan     2.784

# %%
plt.figure(figsize = (15,8))
plt.pie(Asia1.Dystopia,labels=Asia1.Country,autopct='%1.3f%%')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.figure(figsize = (10,5))
plt.xticks(rotation=90)
sns.lineplot(x="Country", y = "Economy", data = Southeast_Asia,marker='o',label='Southeast_Asia')
sns.lineplot(x="Country", y = "Economy", data = South_Asia,marker='o',label='South_Asia')
sns.lineplot(x="Country", y = "Economy", data = East_Asia,marker='o',label='East_Asia')
plt.show()

# %% [markdown]
# Among Asian Countries, India ranks 10th in Economy.

# %%
plt.figure(figsize = (10,5))
plt.xticks(rotation=90)
sns.lineplot(x="Country", y = "Health_Life_Expectancy", data = Southeast_Asia,marker='o',label='Southeast_Asia')
sns.lineplot(x="Country", y = "Health_Life_Expectancy", data = South_Asia,marker='o',label='South_Asia')
sns.lineplot(x="Country", y = "Health_Life_Expectancy", data = East_Asia,marker='o',label='East_Asia')
plt.show()

# %% [markdown]
# Among Asian Countries, India ranks 12th in Healthy Life Expectancy.

# %%
plt.figure(figsize = (16,8))
plt.xticks(rotation=90)
sns.lineplot(x="Country", y = "Corruption", data = Southeast_Asia,marker='o',label='Southeast_Asia')
sns.lineplot(x="Country", y = "Corruption", data = South_Asia,marker='o',label='South_Asia')
sns.lineplot(x="Country", y = "Corruption", data = East_Asia,marker='o',label='East_Asia')
plt.show()

# %% [markdown]
# Among 22 Asian Countries, India ranks 10th in corruption.

# %% [markdown]
# **India and its neighbourhood in 2021**

# %%
df_2021
# Out:
#          Country  ... Dystopia + residual
# 83         China  ...               1.982
# 86         Nepal  ...               2.642
# 100   Bangladesh  ...               2.427
# 104     Pakistan  ...               2.784
# 125      Myanmar  ...               1.407
# 138        India  ...               1.405
# 148  Afghanistan  ...               1.895
#
# [7 rows x 20 columns]

# %% [markdown]
# Logged GDP per capita

# %%
plt.figure(figsize=(10,4))
sns.lineplot(data=df_2021,x="Country",y="Logged GDP per capita",marker='o')
plt.show()

# %% [markdown]
# Among neighbouring countries, India ranks 2nd in the GDP per capita.

# %% [markdown]
# Freedom to make life choices

# %%
plt.figure(figsize=(10,4))
sns.lineplot(data=df_2021,x="Country",y="Freedom",marker='o')
plt.show()

# %% [markdown]
# Among neighbouring countries, India ranks 2nd in the Freedom to make life choices.

# %% [markdown]
# Healthy Life Expectancy

# %%
plt.figure(figsize=(10,4))
sns.lineplot(data=df_2021,x="Country",y="Health_Life_Expectancy",marker='o')
plt.show()

# %% [markdown]
# Among neighbouring countries, India ranks 4th in the Healthy life expectancy

# %% [markdown]
# **# Visualisation of trust across different regions**
#
#  **Satisfaction of people with their governments**

# %%
Trust=df21.groupby(['Region'])[('Explained by: Perceptions of corruption')].mean()
Trust_df=pd.DataFrame(data=Trust)
TRUST=Trust_df.sort_values(by=('Explained by: Perceptions of corruption'),ascending=False,axis=0)
TRUST
# Out:
#                                     Explained by: Perceptions of corruption
# Region
# North America and ANZ                                              0.312750
# Western Europe                                                     0.265524
# East Asia                                                          0.163000
# Southeast Asia                                                     0.146667
# Commonwealth of Independent States                                 0.136667
# Middle East and North Africa                                       0.113000
# Sub-Saharan Africa                                                 0.110583
# Latin America and Caribbean                                        0.093650
# South Asia                                                         0.090571
# Central and Eastern Europe                                         0.056588

# %%
plt.figure(figsize=(10,7))
plt.title('Satisfaction with governments in different regions')
sns.barplot(x=('Explained by: Perceptions of corruption'),y=TRUST.index,data=TRUST,palette='viridis')
plt.show()

# %% [markdown]
# As observed we can see that the North America and ANZ	 has the best trust score.
#
#
# The bottomost regions in the plot have a very low trust score. This could majorly be associated with unhealthy politics and some instances of corruption inside the governments. Unstable authorities are also a major problem leading to a perception of unreliability.

# %% [markdown]
# **Happiness Score of each region in 2021**

# %%
Happiness=df21.groupby(['Region'])['Score'].mean()
Happiness_df=pd.DataFrame(data=Happiness)
SCORE=Happiness_df.sort_values(by='Score',ascending=False,axis=0)
SCORE
# Out:
#                                        Score
# Region
# North America and ANZ               7.128500
# Western Europe                      6.914905
# Central and Eastern Europe          5.984765
# Latin America and Caribbean         5.908050
# East Asia                           5.810333
# Commonwealth of Independent States  5.467000
# Southeast Asia                      5.407556
# Middle East and North Africa        5.219765
# Sub-Saharan Africa                  4.494472
# South Asia                          4.441857

# %%
plt.figure(figsize=(10,7))
plt.title('Happiness score across different regions')
sns.barplot(x='Score',y=SCORE.index,data=SCORE,palette='rocket_r')
plt.show()

# %% [markdown]
# As per the graph,North America and ANZ has the highest happiness score.
# And South Asia in which our country India includes is in the bottom.

# %%
#creating new datasets comprising of below mentioned columns
d21=df21[['Generosity','Family','Score']].copy()
d20=df20[['Generosity','Family','Score']].copy()
d19=df19[['Generosity','Family','Score']].copy()

# %%
plt.figure(figsize=(10,6))
sns.pairplot(d21)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.pairplot(d20)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.pairplot(d19)
plt.show()

# %% [markdown]
# **As we observe in the above scatterplots, the linear relationships described between various factors and the Happiness Score have been justified. Scatter plots are a great source of identifying probable linear relationships between various features and can be used for feature selection.**

# %%
#copy the two columns of df21 and df15 to new frames
d_21=df21[['Country','Score']].copy()
d_15=df15[['Country','Score']].copy()

# %%
#insert the column year to the dataframe
d_21.insert(1, 'Year', '2021')

# %%
d_21
# Out:
#          Country  Year  Score
# 0        Finland  2021  7.842
# 1        Denmark  2021  7.620
# 2    Switzerland  2021  7.571
# 3        Iceland  2021  7.554
# 4    Netherlands  2021  7.464
# ..           ...   ...    ...
# 144      Lesotho  2021  3.512
# 145     Botswana  2021  3.467
# 146       Rwanda  2021  3.415
# 147     Zimbabwe  2021  3.145
# 148  Afghanistan  2021  2.523
#
# [149 rows x 3 columns]

# %%
d_15.insert(1, 'Year', '2015')

# %%
d_15
# Out:
#          Country  Year  Score
# 0    Switzerland  2015  7.587
# 1        Iceland  2015  7.561
# 2        Denmark  2015  7.527
# 3         Norway  2015  7.522
# 4         Canada  2015  7.427
# ..           ...   ...    ...
# 153       Rwanda  2015  3.465
# 154        Benin  2015  3.340
# 155        Syria  2015  3.006
# 156      Burundi  2015  2.905
# 157         Togo  2015  2.839
#
# [158 rows x 3 columns]

# %%
#concatenating two dataframes to new frame to visualize the datas of both years
frames = [d_15, d_21]
result = pd.concat(frames)

# %%
result
# Out:
#          Country  Year  Score
# 0    Switzerland  2015  7.587
# 1        Iceland  2015  7.561
# 2        Denmark  2015  7.527
# 3         Norway  2015  7.522
# 4         Canada  2015  7.427
# ..           ...   ...    ...
# 144      Lesotho  2021  3.512
# 145     Botswana  2021  3.467
# 146       Rwanda  2021  3.415
# 147     Zimbabwe  2021  3.145
# 148  Afghanistan  2021  2.523
#
# [307 rows x 3 columns]

# %% [markdown]
# **Comparing the happiness score of year 2015 and 2021**

# %%
sns.histplot(x='Score',data=result,bins=10,hue='Year',kde=True)
plt.show()

# %% [markdown]
# From the graph,its clear that the happiness score of countries has increased in 2021 compared to 2015.

# %% [markdown]
# **Let’s check which countries are better positioned in each of the aspects being analyzed among top 10 in 2021.**

# %%
fig, axes = plt.subplots(nrows=3, ncols=2,constrained_layout=True,figsize=(10,10))
sns.barplot(x='Economy',y='Country',
                        data=df21.nlargest(10,'Economy'),
                        ax=axes[0,0],palette="Blues_r")
sns.barplot(x='Health_Life_Expectancy' ,y='Country',
                        data=df21.nlargest(10,'Health_Life_Expectancy'),
                        ax=axes[0,1],palette='Blues_r')
sns.barplot(x='Score' ,y='Country',
                        data=df21.nlargest(10,'Score'),
                        ax=axes[1,0],palette='Blues_r')
sns.barplot(x='Generosity' ,y='Country',
                        data=df21.nlargest(10,'Generosity'),
                        ax=axes[1,1],palette='Blues_r')
sns.barplot(x='Freedom' ,y='Country',
                        data=df21.nlargest(10,'Freedom'),
                        ax=axes[2,0],palette='Blues_r')
sns.barplot(x='Corruption' ,y='Country',
                        data=df21.nlargest(10,'Corruption'),
                        ax=axes[2,1],palette='Blues_r')
plt.show()

# %% [markdown]
# In terms of GDP(Economy),Luxumberg tops among all countries.
# In terms of Happiness score Finland grabs the first position.
# Uzbekistan has the most freedom of life.
# Croatia tops in corruption.
# Indonesia is in the first position for generosity.
# In terms of Healthy life expectancy Singapore has the highest score.
